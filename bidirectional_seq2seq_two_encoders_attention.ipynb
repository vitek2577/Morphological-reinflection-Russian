# %%
# !apt-get install -y -qq software-properties-common python-software-properties module-init-tools
# !add-apt-repository -y ppa:alessandro-strada/ppa 2>&1 > /dev/null
# !apt-get update -qq 2>&1 > /dev/null
# !apt-get -y install -qq google-drive-ocamlfuse fuse
from google.colab import auth
auth.authenticate_user()
from oauth2client.client import GoogleCredentials
creds = GoogleCredentials.get_application_default()
import getpass
# !google-drive-ocamlfuse -headless -id={creds.client_id} -secret={creds.client_secret} < /dev/null 2>&1 | grep URL
vcode = getpass.getpass()
# !echo {vcode} | google-drive-ocamlfuse -headless -id={creds.client_id} -secret={creds.client_secret}
# Out:
# E: Package 'python-software-properties' has no installation candidate
# Selecting previously unselected package google-drive-ocamlfuse.
# (Reading database ... 131304 files and directories currently installed.)
# Preparing to unpack .../google-drive-ocamlfuse_0.7.3-0ubuntu3~ubuntu18.04.1_amd64.deb ...
# Unpacking google-drive-ocamlfuse (0.7.3-0ubuntu3~ubuntu18.04.1) ...
# Setting up google-drive-ocamlfuse (0.7.3-0ubuntu3~ubuntu18.04.1) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Please, open the following URL in a web browser: https://accounts.google.com/o/oauth2/auth?client_id=32555940559.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive&response_type=code&access_type=offline&approval_prompt=force
# ··········
# Please, open the following URL in a web browser: https://accounts.google.com/o/oauth2/auth?client_id=32555940559.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive&response_type=code&access_type=offline&approval_prompt=force
# Please enter the verification code: Access token retrieved correctly.

# %%
# !mkdir -p drive
# !google-drive-ocamlfuse drive

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt
import time
from tqdm import tqdm
from tqdm import trange
import matplotlib.ticker as ticker
# %matplotlib inline

import torch
import gc
import torch.nn as nn
from torch import optim
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
from IPython.display import clear_output

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# device = torch.device("cpu")

# %%
start_token = "_"
eos = '#'
MAX_LENGTH = 40

# %%
data_pairs = pd.read_csv("drive/diploma/base_pairs.csv", index_col=0)
data_pairs.loc[:,"word_form"] = data_pairs.word_form.apply(lambda x: start_token + x + eos)
data_pairs.loc[:,"word_norm"] = data_pairs.word_norm.apply(lambda x: start_token + x + eos)
data_pairs.head()
# Out:
# /usr/local/lib/python3.6/dist-packages/numpy/lib/arraysetops.py:569: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)
#    lex_id word_norm word_form       morph_features_form  \
# 0       1      _ёж#     _ежа#  NOUN,anim,masc sing,gent
# 1       1      _ёж#     _ежу#  NOUN,anim,masc sing,datv
# 2       1      _ёж#     _ежа#  NOUN,anim,masc sing,accs
# 3       1      _ёж#    _ежом#  NOUN,anim,masc sing,ablt
# 4       1      _ёж#     _еже#  NOUN,anim,masc sing,loct
#
#         morph_features_norm
# 0  NOUN,anim,masc sing,nomn
# 1  NOUN,anim,masc sing,nomn
# 2  NOUN,anim,masc sing,nomn
# 3  NOUN,anim,masc sing,nomn
# 4  NOUN,anim,masc sing,nomn

# %%
s = "".join(data_pairs.word_form)
tokens = np.sort(np.array(list(set(s))))
    
tok2id = dict(zip(tokens, np.arange(tokens.shape[0])))
id2tok = dict(zip(np.arange(tokens.shape[0]), tokens))

print ('There are {} tokens',len(tokens))

print('Vocabular: ' + "".join(tokens))

# np.save('drive/diploma/vocabulary/tok2id.npy', tok2id) 

# np.save('drive/diploma/vocabulary/id2tok.npy', id2tok)
# Out:
# There are {} tokens 48
# Vocabular: #'-0123456789_абвгдежзийклмнопрстуфхцчшщъыьэюяё’

# %%
import re

set_morph = set()
for i in range(data_pairs.shape[0]):
  loc = re.split(",| ", data_pairs.morph_features_form.values[i])
  for elem in loc:
    set_morph.add(elem)
tokens_f = np.sort(np.array(list(set_morph)))

tok2id_f = dict(zip(tokens_f, np.arange(tokens_f.shape[0])))
# id2tok_f = dict(zip(np.arange(tokens.shape[0]), tokens))

# np.save('drive/diploma/vocabulary/tok2id_f.npy', tok2id_f) 

print ('There are {} tokens',len(tokens_f))

print('Vocabular: ' + "".join(tokens_f))
# Out:
# There are {} tokens 100
# Vocabular: 1per2per3perADJFADJSADVBAbbrAdjxAf-pAnphAnumAproArchCOMPCONJCmp2CollCounDistDmnsErroFimpFixdGNdrGRNDGeoxHypoINFNINTJImpeImpxInfrInitInmxLitrMs-fNOUNNPRONUMRNameOrgnPRCLPREDPREPPRTFPRTSPatrPltmPossPrdxPrntQualQuesSgtmSlngSubxSuprSurnV-beV-biV-ejV-enV-eyV-ieV-oyV-shVERBVpreabltaccsactvanimdatvexclfemnfutrgen1gen2gentimpfimprinaninclindcintrloc1loc2loctmascms-fneutnomnpastperfplurprespssvsingtranvoct

# %%
a = data_pairs.morph_features_form.apply(lambda x: re.split(",| ", x)).values
max_len = 0
for elem in a:
    max_len = max(max_len, len(elem))
print(max_len)
# Out:
# 11

# %%
SOS_token = tok2id[start_token]
EOS_token = tok2id[eos]

# %%
def to_matrix(words, max_len=None, pad=tok2id[eos], dtype=np.int64):
    """Casts a list of words into rnn-digestable matrix"""
    
    max_len = max_len or max(map(len, words))
    words_ix = np.zeros([len(words), max_len], dtype) + pad

    for i in range(len(words)):
        word_ix = list(map(tok2id.get, words[i]))
        words_ix[i, :len(word_ix)] = word_ix

    return words_ix

# %%
print('\n'.join(data_pairs.word_form[:10]))
print(to_matrix(data_pairs.word_form[:10]))
# Out:
# _ежа#
# _ежу#
# _ежа#
# _ежом#
# _еже#
# _ежи#
# _ежей#
# _ежам#
# _ежей#
# _ежами#
# [[13 19 20 14  0  0  0]
#  [13 19 20 33  0  0  0]
#  [13 19 20 14  0  0  0]
#  [13 19 20 28 26  0  0]
#  [13 19 20 19  0  0  0]
#  [13 19 20 22  0  0  0]
#  [13 19 20 19 23  0  0]
#  [13 19 20 14 26  0  0]
#  [13 19 20 19 23  0  0]
#  [13 19 20 14 26 22  0]]

# %%
tok2id_f[eos] = 100

def to_matrix_f(words, max_len=None, pad=tok2id_f[eos], dtype=np.int64):
    """Casts a list of words into rnn-digestable matrix"""
    
    max_len = max_len or max(map(len, words))
    words_ix = np.zeros([len(words), max_len], dtype) + pad

    for i in range(len(words)):
        word_ix = list(map(tok2id_f.get, words[i]))
        words_ix[i, :len(word_ix)] = word_ix

    return words_ix

# %%
# Creating training and validation sets using an 80-20 split

indices = data_pairs.lex_id.unique()
np.random.seed(42)
np.random.shuffle(indices)
data_pairs.set_index("lex_id", inplace=True)
train = data_pairs.loc[indices[:int(0.8 * indices.shape[0])]]
input_train = train.drop("word_form", axis=1)
target_train = train.word_form.values

test = data_pairs.loc[indices[int(0.8 * indices.shape[0]):]]
input_test = test.drop("word_form", axis=1)
target_test = test.word_form.values

# %%
class pairs_Dataset(Dataset):
    def __init__(self, data, data_form):
        self.data = data
        self.target = data_form
    def __len__(self):
        'Denotes the total number of samples'
        return len(self.data)

    def __getitem__(self, index):
        'Generates one sample of data'
        # Select sample
        return self.data.word_norm.values[index], self.data.morph_features_form.values[index], self.target[index], self.data.morph_features_norm.values[index]

# %%
BATCH_SIZE = 512

train_data = pairs_Dataset(input_train, target_train)

dataset = DataLoader(train_data, batch_size=BATCH_SIZE, drop_last=True, shuffle=True)

test_data = pairs_Dataset(input_test, target_test)

test_batches = DataLoader(test_data, batch_size=BATCH_SIZE, drop_last=True, shuffle=True)

# %%
for batch in dataset:
    print(batch)
    print(batch[1])
    print([batch[3][i] + " " + batch[1][i] for i in range(len(batch[3]))])
    print(batch[3] + batch[1])
    break
# Out:
# [('_пересыщавший#', '_экспресс-анализ#', '_нераздробившийся#', '_леечка#', '_засуживавший#', '_растачанный#', '_выпазивший#', '_трусящий#', '_коммунальнее#', '_помуслил#', '_звонимир#', '_перестригаемый#', '_наштукатуривший#', '_комковый#', '_предъявляюсь#', '_сумка#', '_раздоившийся#', '_отцветил#', '_поупражнявший#', '_питый#', '_поворачивающий#', '_полногранный#', '_прокидывающийся#', '_ретардация#', '_освобождённость#', '_токаревы#', '_забредивший#', '_ветчинный#', '_перетянулся#', '_опиливавшийся#', '_вселявший#', '_умнею#', '_пылеочиститель#', '_перелуживаюсь#', '_удержание#', '_пройдошливый#', '_уповаю#', '_дискриминировавший#', '_измочаленный#', '_выселивший#', '_вжавшийся#', '_непоследовательный#', '_алимат#', '_быстролетящий#', '_завёртываюсь#', '_пий#', '_сопатка#', '_ася#', '_составился#', '_надогнут#', '_антиципировавший#', '_неразбухающий#', '_пересдача#', '_вольнодумный#', '_донорский#', '_оброчный#', '_тушёванный#', '_аспидно-чёрный#', '_анзельмович#', '_сошка#', '_асанетович#', '_заменивший#', '_подцветил#', '_краевед#', '_перечитывающийся#', '_скрежетавший#', '_отмин#', '_иступленный#', '_подстерёгший#', '_бегмурат#', '_силосование#', '_выпариваю#', '_подцапнул#', '_насучил#', '_наидревнейший#', '_отшлёпанный#', '_закурчавившийся#', '_перешнуровывающий#', '_гербарный#', '_выманиваю#', '_тяжелораненый#', '_нехотение#', '_варгуза#', '_повергнутый#', '_помрачающий#', '_сметённый#', '_притиснутый#', '_осуждающий#', '_бристоль#', '_дековилька#', '_выдворяю#', '_обратил#', '_библиофил#', '_зафырчавший#', '_двадцатимиллиметровый#', '_печенгский#', '_айзыковна#', '_брянсксантехмонтаж#', '_всечасен#', '_навранный#', '_застеклённый#', '_непахотный#', '_фразированный#', '_оттаивающий#', '_колотильный#', '_ухиченный#', '_гостиничный#', '_навещённый#', '_ораториальный#', '_восхищение#', '_конвейеризация#', '_северо-восточный#', '_замордовывая#', '_покровительство#', '_напаивающийся#', '_ортонормальный#', '_неспособный#', '_факторизация#', '_паломница#', '_гонадотропный#', '_недоговорённость#', '_острокрылый#', '_ариэлевна#', '_киновидеопроизведение#', '_милтоновна#', '_пронзаемый#', '_нурбековна#', '_екимцев#', '_отмаливавший#', '_электрокардиограмма#', '_равносильность#', '_смастерив#', '_мезолитический#', '_аффект#', '_заветный#', '_полугодовой#', '_вытравливаемый#', '_саморазрушительный#', '_долориметрия#', '_девятнадцатилетний#', '_проволочник#', '_припаялся#', '_гелеобразный#', '_расшивающийся#', '_блаженствующий#', '_приписавшийся#', '_прекращавшийся#', '_свиноматочный#', '_краснопивцев#', '_обезземеливание#', '_захаркивающий#', '_предначертанный#', '_линарий#', '_женимый#', '_функционер#', '_затенявшийся#', '_притирающий#', '_звезданувшийся#', '_аффектирующийся#', '_дехлорировавший#', '_петиционный#', '_завздыхал#', '_автоколебательный#', '_спарился#', '_насурьмившийся#', '_заправляющийся#', '_отжигальщик#', '_недодававший#', '_отученный#', '_намолачивающийся#', '_тревоживший#', '_истыканный#', '_натруживавший#', '_подтяпанный#', '_ляпавшийся#', '_дублённый#', '_дерущий#', '_обслюнивать#', '_арсма#', '_располагавший#', '_нижполиграф#', '_почвенность#', '_манишов#', '_снегур#', '_перештукатуривавшийся#', '_жамбал#', '_непонятийный#', '_обессудить#', '_шалюемый#', '_обтрёпывавшийся#', '_поведенческий#', '_недоливающийся#', '_борнмут#', '_закольцованный#', '_аракаевский#', '_манёврен#', '_андрушко#', '_разбушевавшийся#', '_альфон#', '_изгоняющийся#', '_шаброванный#', '_выкапчиваюсь#', '_переморил#', '_перекопировавший#', '_подотчётный#', '_прима#', '_лоботрясничаю#', '_унизывающий#', '_встряхнувшийся#', '_подпоясываем#', '_кирасирский#', '_квотирующий#', '_искендаровна#', '_кособокий#', '_скорпионоподобный#', '_бакальский#', '_разгонистый#', '_кальцинировавший#', '_нажимавшийся#', '_дюкарев#', '_подутюживавшийся#', '_уморившийся#', '_натягивавшийся#', '_дистрибутирован#', '_гипокристаллический#', '_кабацкий#', '_оттолканный#', '_наквашивающий#', '_ответствующий#', '_арсаланович#', '_привянув#', '_небалансирный#', '_ай ...
# ('PRTF,impf,tran,past,actv neut,sing,loct', 'NOUN,inan,masc plur,ablt', 'ADJF masc,sing,gent', 'NOUN,inan,femn plur,gent', 'PRTF,impf,tran,past,actv neut,sing,nomn', 'PRTF,perf,tran,past,pssv plur,gent', 'PRTF,perf,tran,past,actv plur,gent', 'PRTF,impf,intr,pres,actv inan,masc,sing,accs', 'COMP Cmp2', 'VERB,perf,tran neut,sing,past,indc', 'NOUN,anim,masc,Name plur,loct', 'PRTF,impf,tran,pres,pssv femn,sing,accs', 'PRTF,perf,tran,past,actv plur,gent', 'ADJF masc,sing,gent', 'VERB,impf,intr plur,2per,pres,indc', 'NOUN,inan,femn plur,datv', 'PRTF,perf,intr,past,actv masc,sing,loct', 'VERB,perf,tran plur,3per,futr,indc', 'PRTF,perf,tran,past,actv neut,sing,accs', 'PRTF,impf,tran,past,pssv inan,masc,sing,accs', 'PRTF,impf,tran,pres,actv masc,sing,loct', 'ADJF femn,sing,loct', 'PRTF,impf,intr,pres,actv masc,sing,loct', 'NOUN,inan,femn plur,ablt', 'NOUN,inan,femn plur,loct', 'NOUN,anim,ms-f,Pltm,Surn plur,datv', 'PRTF,perf,intr,past,actv neut,sing,loct', 'ADJF,Qual femn,sing,ablt', 'VERB,perf,intr sing,1per,futr,indc', 'PRTF,impf,intr,past,actv femn,sing,nomn', 'PRTF,impf,tran,past,actv inan,masc,sing,accs', 'VERB,impf,intr masc,sing,past,indc', 'NOUN,inan,masc plur,nomn', 'VERB,impf,intr plur,past,indc', 'NOUN,inan,neut sing,ablt,V-be', 'ADJF masc,sing,gent', 'VERB,impf,intr plur,2per,pres,indc', 'PRTF,impf,tran,past,actv anim,masc,sing,accs', 'PRTF,perf,tran,past,pssv masc,sing,datv', 'PRTF,perf,tran,past,actv femn,sing,ablt', 'PRTF,perf,intr,past,actv masc,sing,loct', 'ADJF,Qual femn,sing,datv', 'NOUN,anim,masc,Name sing,loct', 'ADJF inan,plur,accs', 'VERB,impf,intr femn,sing,past,indc', 'NOUN,anim,masc,Name sing,gent', 'NOUN,inan,femn sing,ablt', 'NOUN,anim,femn,Name plur,gent', 'VERB,perf,intr sing,2per,futr,indc', 'PRTS,perf,past,pssv neut,sing', 'PRTF,perf,tran,past,actv femn,sing,ablt', 'ADJF femn,sing,ablt', 'NOUN,inan,femn plur,datv', 'ADJF,Qual femn,sing,datv', 'ADJF neut,sing,gent', 'ADJF,Qual femn,sing,loct', 'PRTF,impf,tran,past,pssv anim,plur,accs', 'ADJF masc,sing,loct', 'NOUN,anim,masc,Patr plur,nomn', 'NOUN,inan,femn sing,datv', 'NOUN,anim,masc,Patr plur,gent', 'PRTF,perf,tran,past,actv femn,sing,accs', 'VERB,perf,tran plur,3per,futr,indc', 'NOUN,anim,masc sing,accs', 'PRTF,impf,intr,pres,actv masc,sing,datv', 'PRTF,impf,intr,past,actv neut,sing,accs', 'NOUN,inan,masc sing,datv', 'PRTF,perf,tran,past,pssv femn,sing,gent', 'PRTF,perf,tran,past,actv neut,sing,loct', 'NOUN,anim,masc,Name sing,datv', 'NOUN,inan,neut sing,ablt,V-be', 'VERB,impf,tran plur,2per,pres,indc', 'VERB,perf,tran sing,impr,excl', 'VERB,perf,tran neut,sing,past,indc', 'ADJF,Supr,Qual neut,sing,loct', 'PRTF,perf,tran,past,pssv masc,sing,loct', 'PRTF,perf,intr,past,actv inan,plur,accs', 'PRTF,impf,tran,pres,actv neut,sing,loct', 'ADJF femn,sing,nomn', 'VERB,impf,tran plur,3per,pres,indc', 'ADJF neut,sing,loct', 'NOUN,inan,neut plur,nomn', 'NOUN,inan,femn,Sgtm,Geox sing,ablt', 'PRTF,perf,tran,past,pssv femn,sing,ablt,V-oy', 'PRTF,impf,tran,pres,actv anim,plur,accs', 'PRTF,perf,tran,past,pssv neut,sing,ablt', 'PRTF,perf,tran,past,pssv inan,plur,accs', 'PRTF,impf,tran,pres,actv,Adjx plur,nomn', 'NOUN,inan,masc sing,ablt', 'NOUN,inan,femn sing,ablt,V-oy', 'VERB,impf,tran plur,past,indc', 'VERB,perf,tran plur,impr,excl', 'NOUN,anim,masc sing,ablt', 'PRTF,perf,intr,past,actv neut,sing,ablt', 'ADJF femn,sing,gent', 'ADJF anim,masc,sing,accs', 'NOUN,anim,femn,Patr sing,gent', 'NOUN,inan,masc,Orgn sing,ablt,Infr', 'ADJS,Qual neut,sing', 'PRTF,perf,tran,past,pssv anim,plur,accs', 'PRTF,perf,tran,past,pssv masc,sing,datv', 'ADJF plur,gent', 'PRTF,impf,tran,past,pssv masc,sing,datv', 'PRTF,impf,tran,pres,actv neut,sing,loct', 'ADJF femn,sing,nomn', 'PRTF,perf,tran,past,pssv neut,sing,loct', 'ADJF neut,sing,accs', 'PRTF,perf,tran,past,pssv neut,sing,nomn', 'ADJF femn,sing,ablt', 'NOUN,inan,neut sing,accs', 'NOUN,inan,femn sing,ablt', 'ADJF neut,sing,datv', 'GRND,impf,tran past,V-sh', 'NOUN,inan,neut sing,gent', 'PRTF,impf,intr,pres,actv femn,sing,ablt', 'ADJF fem ...
# ['PRTF,impf,tran,past,actv masc,sing,nomn PRTF,impf,tran,past,actv neut,sing,loct', 'NOUN,inan,masc sing,nomn NOUN,inan,masc plur,ablt', 'ADJF masc,sing,nomn ADJF masc,sing,gent', 'NOUN,inan,femn sing,nomn NOUN,inan,femn plur,gent', 'PRTF,impf,tran,past,actv masc,sing,nomn PRTF,impf,tran,past,actv neut,sing,nomn', 'PRTF,perf,tran,past,pssv masc,sing,nomn PRTF,perf,tran,past,pssv plur,gent', 'PRTF,perf,tran,past,actv masc,sing,nomn PRTF,perf,tran,past,actv plur,gent', 'PRTF,impf,intr,pres,actv masc,sing,nomn PRTF,impf,intr,pres,actv inan,masc,sing,accs', 'COMP COMP Cmp2', 'VERB,perf,tran masc,sing,past,indc VERB,perf,tran neut,sing,past,indc', 'NOUN,anim,masc,Name sing,nomn NOUN,anim,masc,Name plur,loct', 'PRTF,impf,tran,pres,pssv masc,sing,nomn PRTF,impf,tran,pres,pssv femn,sing,accs', 'PRTF,perf,tran,past,actv masc,sing,nomn PRTF,perf,tran,past,actv plur,gent', 'ADJF masc,sing,nomn ADJF masc,sing,gent', 'VERB,impf,intr sing,1per,pres,indc VERB,impf,intr plur,2per,pres,indc', 'NOUN,inan,femn sing,nomn NOUN,inan,femn plur,datv', 'PRTF,perf,intr,past,actv masc,sing,nomn PRTF,perf,intr,past,actv masc,sing,loct', 'VERB,perf,tran masc,sing,past,indc VERB,perf,tran plur,3per,futr,indc', 'PRTF,perf,tran,past,actv masc,sing,nomn PRTF,perf,tran,past,actv neut,sing,accs', 'PRTF,impf,tran,past,pssv masc,sing,nomn PRTF,impf,tran,past,pssv inan,masc,sing,accs', 'PRTF,impf,tran,pres,actv masc,sing,nomn PRTF,impf,tran,pres,actv masc,sing,loct', 'ADJF masc,sing,nomn ADJF femn,sing,loct', 'PRTF,impf,intr,pres,actv masc,sing,nomn PRTF,impf,intr,pres,actv masc,sing,loct', 'NOUN,inan,femn sing,nomn NOUN,inan,femn plur,ablt', 'NOUN,inan,femn sing,nomn NOUN,inan,femn plur,loct', 'NOUN,anim,ms-f,Pltm,Surn plur,nomn NOUN,anim,ms-f,Pltm,Surn plur,datv', 'PRTF,perf,intr,past,actv masc,sing,nomn PRTF,perf,intr,past,actv neut,sing,loct', 'ADJF,Qual masc,sing,nomn ADJF,Qual femn,sing,ablt', 'VERB,perf,intr masc,sing,past,indc VERB,perf,intr sing,1per,futr,indc', 'PRTF,impf,intr,past,actv masc,sing,nomn PRTF,impf,intr,past,actv femn,sing,nomn', 'PRTF,impf,tran,past,actv masc,sing,nomn PRTF,impf,tran,past,actv inan,masc,sing,accs', 'VERB,impf,intr sing,1per,pres,indc VERB,impf,intr masc,sing,past,indc', 'NOUN,inan,masc sing,nomn NOUN,inan,masc plur,nomn', 'VERB,impf,intr sing,1per,pres,indc VERB,impf,intr plur,past,indc', 'NOUN,inan,neut sing,nomn NOUN,inan,neut sing,ablt,V-be', 'ADJF masc,sing,nomn ADJF masc,sing,gent', 'VERB,impf,intr sing,1per,pres,indc VERB,impf,intr plur,2per,pres,indc', 'PRTF,impf,tran,past,actv masc,sing,nomn PRTF,impf,tran,past,actv anim,masc,sing,accs', 'PRTF,perf,tran,past,pssv masc,sing,nomn PRTF,perf,tran,past,pssv masc,sing,datv', 'PRTF,perf,tran,past,actv masc,sing,nomn PRTF,perf,tran,past,actv femn,sing,ablt', 'PRTF,perf,intr,past,actv masc,sing,nomn PRTF,perf,intr,past,actv masc,sing,loct', 'ADJF,Qual masc,sing,nomn ADJF,Qual femn,sing,datv', 'NOUN,anim,masc,Name sing,nomn NOUN,anim,masc,Name sing,loct', 'ADJF masc,sing,nomn ADJF inan,plur,accs', 'VERB,impf,intr sing,1per,pres,indc VERB,impf,intr femn,sing,past,indc', 'NOUN,anim,masc,Name sing,nomn NOUN,anim,masc,Name sing,gent', 'NOUN,inan,femn sing,nomn NOUN,inan,femn sing,ablt', 'NOUN,anim,femn,Name sing,nomn NOUN,anim,femn,Name plur,gent', 'VERB,perf,intr masc,sing,past,indc VERB,perf,intr sing,2per,futr,indc', 'PRTS,perf,past,pssv masc,sing PRTS,perf,past,pssv neut,sing', 'PRTF,perf,tran,past,actv masc,sing,nomn PRTF,perf,tran,past,actv femn,sing,ablt', 'ADJF masc,sing,nomn ADJF femn,sing,ablt', 'NOUN,inan,femn sing,nomn NOUN,inan,femn plur,datv', 'ADJF,Qual masc,sing,nomn ADJF,Qual femn,sing,datv', 'ADJF masc,sing,nomn ADJF neut,sing,gent', 'ADJF,Qual masc,sing,nomn ADJF,Qual femn,sing,loct', 'PRTF,impf,tran,past,pssv masc,sing,nomn PRTF,impf,tran,past,pssv anim,plur,accs', 'ADJF masc,sing,nomn ADJF masc,sing,loct', 'NOUN,anim,masc,Patr sing,nomn NOUN,anim,masc,Patr plur,nomn', 'NOUN,inan,femn sing,nomn NOUN,inan,femn sing,datv', 'NOUN,anim,masc,Patr sing,nomn NOUN,ani ...
# ('PRTF,impf,tran,past,actv masc,sing,nomn', 'NOUN,inan,masc sing,nomn', 'ADJF masc,sing,nomn', 'NOUN,inan,femn sing,nomn', 'PRTF,impf,tran,past,actv masc,sing,nomn', 'PRTF,perf,tran,past,pssv masc,sing,nomn', 'PRTF,perf,tran,past,actv masc,sing,nomn', 'PRTF,impf,intr,pres,actv masc,sing,nomn', 'COMP', 'VERB,perf,tran masc,sing,past,indc', 'NOUN,anim,masc,Name sing,nomn', 'PRTF,impf,tran,pres,pssv masc,sing,nomn', 'PRTF,perf,tran,past,actv masc,sing,nomn', 'ADJF masc,sing,nomn', 'VERB,impf,intr sing,1per,pres,indc', 'NOUN,inan,femn sing,nomn', 'PRTF,perf,intr,past,actv masc,sing,nomn', 'VERB,perf,tran masc,sing,past,indc', 'PRTF,perf,tran,past,actv masc,sing,nomn', 'PRTF,impf,tran,past,pssv masc,sing,nomn', 'PRTF,impf,tran,pres,actv masc,sing,nomn', 'ADJF masc,sing,nomn', 'PRTF,impf,intr,pres,actv masc,sing,nomn', 'NOUN,inan,femn sing,nomn', 'NOUN,inan,femn sing,nomn', 'NOUN,anim,ms-f,Pltm,Surn plur,nomn', 'PRTF,perf,intr,past,actv masc,sing,nomn', 'ADJF,Qual masc,sing,nomn', 'VERB,perf,intr masc,sing,past,indc', 'PRTF,impf,intr,past,actv masc,sing,nomn', 'PRTF,impf,tran,past,actv masc,sing,nomn', 'VERB,impf,intr sing,1per,pres,indc', 'NOUN,inan,masc sing,nomn', 'VERB,impf,intr sing,1per,pres,indc', 'NOUN,inan,neut sing,nomn', 'ADJF masc,sing,nomn', 'VERB,impf,intr sing,1per,pres,indc', 'PRTF,impf,tran,past,actv masc,sing,nomn', 'PRTF,perf,tran,past,pssv masc,sing,nomn', 'PRTF,perf,tran,past,actv masc,sing,nomn', 'PRTF,perf,intr,past,actv masc,sing,nomn', 'ADJF,Qual masc,sing,nomn', 'NOUN,anim,masc,Name sing,nomn', 'ADJF masc,sing,nomn', 'VERB,impf,intr sing,1per,pres,indc', 'NOUN,anim,masc,Name sing,nomn', 'NOUN,inan,femn sing,nomn', 'NOUN,anim,femn,Name sing,nomn', 'VERB,perf,intr masc,sing,past,indc', 'PRTS,perf,past,pssv masc,sing', 'PRTF,perf,tran,past,actv masc,sing,nomn', 'ADJF masc,sing,nomn', 'NOUN,inan,femn sing,nomn', 'ADJF,Qual masc,sing,nomn', 'ADJF masc,sing,nomn', 'ADJF,Qual masc,sing,nomn', 'PRTF,impf,tran,past,pssv masc,sing,nomn', 'ADJF masc,sing,nomn', 'NOUN,anim,masc,Patr sing,nomn', 'NOUN,inan,femn sing,nomn', 'NOUN,anim,masc,Patr sing,nomn', 'PRTF,perf,tran,past,actv masc,sing,nomn', 'VERB,perf,tran masc,sing,past,indc', 'NOUN,anim,masc sing,nomn', 'PRTF,impf,intr,pres,actv masc,sing,nomn', 'PRTF,impf,intr,past,actv masc,sing,nomn', 'NOUN,inan,masc sing,nomn', 'PRTF,perf,tran,past,pssv masc,sing,nomn', 'PRTF,perf,tran,past,actv masc,sing,nomn', 'NOUN,anim,masc,Name sing,nomn', 'NOUN,inan,neut sing,nomn', 'VERB,impf,tran sing,1per,pres,indc', 'VERB,perf,tran masc,sing,past,indc', 'VERB,perf,tran masc,sing,past,indc', 'ADJF,Supr,Qual masc,sing,nomn', 'PRTF,perf,tran,past,pssv masc,sing,nomn', 'PRTF,perf,intr,past,actv masc,sing,nomn', 'PRTF,impf,tran,pres,actv masc,sing,nomn', 'ADJF masc,sing,nomn', 'VERB,impf,tran sing,1per,pres,indc', 'ADJF masc,sing,nomn', 'NOUN,inan,neut sing,nomn', 'NOUN,inan,femn,Sgtm,Geox sing,nomn', 'PRTF,perf,tran,past,pssv masc,sing,nomn', 'PRTF,impf,tran,pres,actv masc,sing,nomn', 'PRTF,perf,tran,past,pssv masc,sing,nomn', 'PRTF,perf,tran,past,pssv masc,sing,nomn', 'PRTF,impf,tran,pres,actv,Adjx masc,sing,nomn', 'NOUN,inan,masc sing,nomn', 'NOUN,inan,femn sing,nomn', 'VERB,impf,tran sing,1per,pres,indc', 'VERB,perf,tran masc,sing,past,indc', 'NOUN,anim,masc sing,nomn', 'PRTF,perf,intr,past,actv masc,sing,nomn', 'ADJF masc,sing,nomn', 'ADJF masc,sing,nomn', 'NOUN,anim,femn,Patr sing,nomn', 'NOUN,inan,masc,Orgn sing,nomn', 'ADJS,Qual masc,sing', 'PRTF,perf,tran,past,pssv masc,sing,nomn', 'PRTF,perf,tran,past,pssv masc,sing,nomn', 'ADJF masc,sing,nomn', 'PRTF,impf,tran,past,pssv masc,sing,nomn', 'PRTF,impf,tran,pres,actv masc,sing,nomn', 'ADJF masc,sing,nomn', 'PRTF,perf,tran,past,pssv masc,sing,nomn', 'ADJF masc,sing,nomn', 'PRTF,perf,tran,past,pssv masc,sing,nomn', 'ADJF masc,sing,nomn', 'NOUN,inan,neut sing,nomn', 'NOUN,inan,femn sing,nomn', 'ADJF masc,sing,nomn', 'GRND,impf,tran pres', 'NOUN,inan,neut sing,nomn', 'PRTF,impf,intr,pres,actv masc,sing,nomn', 'ADJF masc,sing,nomn', ' ...

# %%
class EncoderRNN(nn.Module):
    def __init__(self, input_size, hidden_size):
        super(EncoderRNN, self).__init__()
        self.hidden_size = hidden_size
        self.batch_size = BATCH_SIZE
        self.embedding = nn.Embedding(input_size, hidden_size)
        self.gru = nn.GRU(hidden_size, hidden_size, bidirectional=True)

    def forward(self, input, hidden):
        embedded = self.embedding(input).view(1, self.batch_size, -1)
        output = embedded
        output, hidden = self.gru(output, hidden)
        return output, hidden

    def initHidden(self):
        return torch.zeros(2, self.batch_size, self.hidden_size, device=device)

# %%
class AttnDecoderRNN(nn.Module):
    def __init__(self, hidden_size, output_size, morph_feat_size, dropout_p=0.1, max_length=MAX_LENGTH):
        super(AttnDecoderRNN, self).__init__()
        self.hidden_size = hidden_size
        self.output_size = output_size
        self.morph_size = morph_feat_size
        self.batch_size = BATCH_SIZE
        self.dropout_p = dropout_p
        self.max_length = max_length

        self.embedding = nn.Embedding(self.output_size, self.hidden_size)
        self.attn = nn.Linear(self.hidden_size * 3, self.max_length)
        self.attn_combine = nn.Linear(self.hidden_size * 3, self.hidden_size)
        
        self.embedding_morph = nn.Embedding(self.morph_size, self.hidden_size)
        self.attn_morph = nn.Linear(3328, 22)
        self.attn_combine_morph = nn.Linear(3328, self.hidden_size)
        self.dropout = nn.Dropout(self.dropout_p)
        self.gru = nn.GRU(2 * self.hidden_size, self.hidden_size * 2)
        self.out = nn.Linear(self.hidden_size * 2, self.output_size)

    def forward(self, input, input_feat, feat_enc_out, morph_feat_hidden, hidden, encoder_outputs):
        embedded = self.embedding(input).view(1, self.batch_size, -1)
        embedded = self.dropout(embedded)
        attn_weights = F.softmax(
            self.attn(torch.cat((embedded[0], hidden[0]), 1)), dim=1)
        attn_applied = torch.bmm(attn_weights.unsqueeze(1),
                                 encoder_outputs)
        output = torch.cat((embedded[0], attn_applied.squeeze()), 1)
        output = self.attn_combine(output).unsqueeze(0)
        output = F.relu(output)
        
        embedded_morph = self.embedding_morph(input_feat).view(1, self.batch_size, -1)
        attn_weights_morph = F.softmax(
            self.attn_morph(torch.cat((embedded_morph[0], hidden[0]), 1)), dim=1)
        
        attn_applied = torch.bmm(attn_weights_morph.unsqueeze(1),
                                 feat_enc_out)
        output_morph = torch.cat((embedded_morph[0], attn_applied.squeeze()), 1)
        output_morph = self.attn_combine_morph(output_morph).unsqueeze(0)
        output_morph = F.relu(output_morph)
        
        output = torch.cat((output, output_morph), 2)
        output, hidden = self.gru(output, hidden)

        output = F.log_softmax(self.out(output[0]), dim=1)
        return output, hidden, attn_weights

    def initHidden(self):
        return torch.zeros(1, self.batch_size, self.hidden_size, device=device)

# %%
teacher_forcing_ratio = 0.5

def train_batch(X, X_f, y, encoder, encoder_f, decoder, encoder_opt, encoder_f_opt, decoder_opt, criterion, lr, max_length=MAX_LENGTH):
    encoder_hidden = encoder.initHidden()
    encoder_hidden_f = encoder_f.initHidden()
    
    encoder.train()
    encoder_f.train()
    decoder.train()
    
    encoder_opt.zero_grad()
    encoder_f_opt.zero_grad()
    decoder_opt.zero_grad()
    max_length = X.shape[1]
    encoder_outputs = torch.zeros(BATCH_SIZE, max_length, encoder.hidden_size * 2, device=device)
    encoder_outputs_f = torch.zeros(BATCH_SIZE, 22, encoder.hidden_size * 2, device=device)
    loss = 0
    for i in range(X.shape[1]):
        encoder_output, encoder_hidden = encoder(
            X[:, i], encoder_hidden)
        encoder_outputs[:, i] = encoder_output[0]
    for i in range(X_f.shape[1]):
        encoder_output_f, encoder_hidden_f = encoder_f(
            X_f[:, i], encoder_hidden_f)
        encoder_outputs_f[:, i] = encoder_output_f[0]

    decoder_input = torch.tensor([[int(SOS_token)] * BATCH_SIZE], device=device)

    decoder_hidden = encoder_hidden.reshape(1, BATCH_SIZE, -1)

    use_teacher_forcing = True if np.random.random() < teacher_forcing_ratio else False

    if use_teacher_forcing:
        # Teacher forcing: Feed the target as the next input
        for di in range(y.shape[1]):
            decoder_output, decoder_hidden, decoder_attention = decoder(
                decoder_input, X_f,  encoder_outputs_f, encoder_hidden_f, decoder_hidden, encoder_outputs)
            loss += criterion(decoder_output, y[:, di])
            decoder_input = y[:, di]  # Teacher forcing

    else:
        # Without teacher forcing: use its own predictions as the next input
        for di in range(y.shape[1]):
            decoder_output, decoder_hidden, decoder_attention = decoder(
                decoder_input, X_f, encoder_outputs_f, encoder_hidden_f, decoder_hidden, encoder_outputs)
            topv, topi = decoder_output.topk(1)
            decoder_input = topi.squeeze().detach()  # detach from history as input

            loss += criterion(decoder_output, y[:, di])

    loss.backward()
    torch.nn.utils.clip_grad_norm_(encoder.parameters(), 0.5)
    torch.nn.utils.clip_grad_norm_(encoder_f.parameters(), 0.5)
    torch.nn.utils.clip_grad_norm_(decoder.parameters(), 0.5)
    for p in encoder.parameters():
      p.data.add_(-lr, p.grad.data)
    for p in encoder_f.parameters():
      p.data.add_(-lr, p.grad.data)
    for p in decoder.parameters():
      p.data.add_(-lr, p.grad.data)
    encoder_opt.step()
    encoder_f_opt.step()
    decoder_opt.step()

    return loss.item()

# %%
def plot_history(train_history, title='loss'):
    plt.figure()
    plt.title('{}'.format(title))
    plt.plot(train_history, label='train', zorder=1)    
    plt.xlabel('train steps')
    plt.grid()
    plt.show()
    
    
def test(encoder, encoder_f, decoder, criterion, test_batches, loss_log, acc_log):
    encoder.eval()
    encoder_f.eval()
    decoder.eval()
    for batch_num, batch in zip(trange(len(test_batches)), test_batches):
        encoder_hidden = encoder.initHidden()
        encoder_hidden_f = encoder_f.initHidden()
        max_len = max(max(map(len, batch[0])), max(map(len, batch[2])))
        X = torch.from_numpy(to_matrix(batch[0], max_len=MAX_LENGTH)).to(device)
        X_f = torch.from_numpy(to_matrix_f(np.array([re.split(",| ", batch[1][i]) for i in range(len(batch[1]))]), max_len=11)).to(device)
        y = torch.from_numpy(to_matrix(batch[2], max_len=MAX_LENGTH)).to(device)
        
        max_length = X.shape[1]
        encoder_outputs = torch.zeros(BATCH_SIZE, max_length, encoder.hidden_size * 2, device=device)
        encoder_outputs_f = torch.zeros(BATCH_SIZE, 22, encoder.hidden_size * 2, device=device)
        loss = 0
        acc = 0
        for i in range(X.shape[1]):
            encoder_output, encoder_hidden = encoder(
                X[:, i], encoder_hidden)
            encoder_outputs[:, i] = encoder_output[0]
            
        for i in range(X_f.shape[1]):
            encoder_output_f, encoder_hidden_f = encoder_f(
                X_f[:, i], encoder_hidden_f)
            encoder_outputs_f[:, i] = encoder_output_f[0]
            
        decoder_input = torch.tensor([[int(SOS_token)] * BATCH_SIZE], device=device)

        decoder_hidden = encoder_hidden.reshape(1, BATCH_SIZE, -1)
        decoder_pred = []
        for di in range(y.shape[1]):
            decoder_output, decoder_hidden, decoder_attention = decoder(
                decoder_input, X_f, encoder_outputs_f, encoder_hidden_f, decoder_hidden, encoder_outputs)
            
            topv, topi = decoder_output.topk(1)
            decoder_input = topi.squeeze().detach()  # detach from history as input
            loss += criterion(decoder_output, y[:, di])
            decoder_pred.append(decoder_input.cpu())
        res = np.vstack(decoder_pred).T
        pred_res = ["".join(id2tok[_] for _ in res[i]) for i in range(res.shape[0])]
        true_res = ["".join(id2tok[_] for _ in y.cpu().numpy()[i]) for i in range(y.shape[0])]
        acc = accuracy_score(pred_res, true_res)
        loss_log.append(float(loss) / X.shape[0])
        acc_log.append(acc)
    plot_history(loss_log, title="Test")
    plot_history(acc_log, title="Accuracy")
    print("Mean accuracy - {}".format(np.mean(acc_log)))
    return loss_log

def train(data, test_batches, encoder, encoder_f, decoder, encoder_optimizer, decoder_optimizer, encoder_f_optimizer, n_epochs, print_every=1, plot_every=1, lr=0.005):
    start = time.time()
    plot_losses = []
    loss_log = []
    acc_log = []
    criterion = nn.NLLLoss()
    lr_decay_base = 1 / 1.15
    m_flat_lr = 10.0
    for epoch in range(n_epochs):
        encoder.train()
        decoder.train()
        loss = 0
        lr_decay = lr_decay_base ** max(epoch - m_flat_lr, 0)
        lr = lr * lr_decay
        for batch_num, batch in zip(trange(len(data)), data):
            max_len = max(max(map(len, batch[0])), max(map(len, batch[2])))
            X = torch.from_numpy(to_matrix(batch[0], max_len=MAX_LENGTH)).to(device)
            X_f = torch.from_numpy(to_matrix_f(np.array([re.split(",| ", batch[1][i]) for i in range(len(batch[1]))]), max_len=11)).to(device)
            y = torch.from_numpy(to_matrix(batch[2], max_len=MAX_LENGTH)).to(device)
            loss = train_batch(X, X_f, y, encoder, encoder_f,
                     decoder, encoder_optimizer, encoder_f_optimizer, decoder_optimizer, criterion, lr)
            plot_losses.append(loss / X.shape[0])
        clear_output()
        gc.collect()
        print("Loss - {}".format(loss))
        print("Epoch - {}".format(epoch))
        plot_history(plot_losses, "Train")
        torch.save({
            'encoder1_state_dict': encoder.state_dict(),
            'encoder2_state_dict': encoder_f.state_dict(),
            'attn_decoder1_state_dict': decoder.state_dict(),
            'encoder_optimizer_state_dict': encoder_optimizer.state_dict(),
            'encoder_f_optimizer_state_dict': encoder_f_optimizer.state_dict(),
            'decoder_optimizer_state_dict': decoder_optimizer.state_dict()
            }, "drive/diploma/bidirectional/two_encoders_unidir_GRU_{}".format(epoch))
    gc.collect()
    test(encoder, encoder_f, decoder, criterion, test_batches, loss_log, acc_log)

# %%
hidden_size = 256
learning_rate = 0.01
encoder1 = EncoderRNN(tokens.shape[0], hidden_size).to(device)
encoder2 = EncoderRNN(tokens_f.shape[0] + 1, hidden_size).to(device)
attn_decoder1 = AttnDecoderRNN(hidden_size, tokens.shape[0], tokens_f.shape[0] + 1, dropout_p=0.1).to(device)

encoder_optimizer = optim.SGD(encoder1.parameters(), lr=learning_rate)
decoder_optimizer = optim.SGD(attn_decoder1.parameters(), lr=learning_rate)
encoder_f_optimizer = optim.SGD(encoder2.parameters(), lr=learning_rate)

# %%
train(dataset, test_batches, encoder1, encoder2, attn_decoder1, encoder_optimizer, decoder_optimizer, encoder_f_optimizer, 5)
# Out:
# Loss - 4.690522193908691
# Epoch - 4
# 100%|██████████| 1860/1860 [04:45<00:00,  6.57it/s]
# Mean accuracy - 0.4635889196908602

# %%
# всего 19
train(dataset, test_batches, encoder1, encoder2, attn_decoder1, encoder_optimizer, decoder_optimizer, encoder_f_optimizer, 2)
# Out:
# Loss - 0.10994668304920197
# Epoch - 1
# 100%|██████████| 1860/1860 [04:48<00:00,  6.54it/s]
# Mean accuracy - 0.9879620295698924

# %%
checkpoint = torch.load("drive/diploma/bidirectional/two_encoders_unidir_GRU_1")
encoder1.load_state_dict(checkpoint['encoder1_state_dict'])
encoder_optimizer.load_state_dict(checkpoint['encoder_optimizer_state_dict'])

encoder2.load_state_dict(checkpoint['encoder2_state_dict'])
encoder_f_optimizer.load_state_dict(checkpoint['encoder_f_optimizer_state_dict'])


attn_decoder1.load_state_dict(checkpoint['attn_decoder1_state_dict'])
decoder_optimizer.load_state_dict(checkpoint['decoder_optimizer_state_dict'])

# %%
# !pip install pymorphy2
# Out:
# Collecting pymorphy2
#   Downloading https://files.pythonhosted.org/packages/a3/33/fff9675c68b5f6c63ec8c6e6ff57827dda28a1fa5b2c2d727dffff92dd47/pymorphy2-0.8-py2.py3-none-any.whl (46kB)
#     100% |████████████████████████████████| 51kB 6.5MB/s
# Collecting pymorphy2-dicts<3.0,>=2.4 (from pymorphy2)
#   Downloading https://files.pythonhosted.org/packages/02/51/2465fd4f72328ab50877b54777764d928da8cb15b74e2680fc1bd8cb3173/pymorphy2_dicts-2.4.393442.3710985-py2.py3-none-any.whl (7.1MB)
#     100% |████████████████████████████████| 7.1MB 5.1MB/s
# Collecting dawg-python>=0.7 (from pymorphy2)
#   Downloading https://files.pythonhosted.org/packages/6a/84/ff1ce2071d4c650ec85745766c0047ccc3b5036f1d03559fd46bb38b5eeb/DAWG_Python-0.7.2-py2.py3-none-any.whl
# Requirement already satisfied: docopt>=0.6 in /usr/local/lib/python3.6/dist-packages (from pymorphy2) (0.6.2)
# Installing collected packages: pymorphy2-dicts, dawg-python, pymorphy2
# Successfully installed dawg-python-0.7.2 pymorphy2-0.8 pymorphy2-dicts-2.4.393442.3710985

# %%
import pymorphy2

acc_log = []
morph = pymorphy2.MorphAnalyzer()
t = 0
for batch_num, batch in zip(trange(len(test_batches)), test_batches):
  X = batch[0]
  X_f = np.array([re.split(",| ", batch[1][i]) for i in range(len(batch[1]))])
  y = batch[2]
  norm_form = np.array([re.split(",| ", batch[3][i]) for i in range(len(batch[1]))])
  acc = 0
  neg_acc = 0
  for i in range(len(X)):
    py_lemmas = morph.parse(X[i][1:-1])
    morph_set = set(X_f[i])
    py_lemma = 0
    if "ms-f" in norm_form[i]:
      for j, elem in enumerate(norm_form[i]):
        if elem == "ms-f":
          norm_form[i][j] = "Ms-f"
    for p_lem in py_lemmas:
      if set(norm_form[i]) in p_lem.tag:
        py_lemma = p_lem
    try: 
      pred = py_lemma.inflect(morph_set).word
    except:
      t += 1
     
    acc += pred == y[i][1:-1]
    neg_acc += pred != y[i][1:-1]
  acc_log.append(acc / (acc + neg_acc))
plot_history(acc_log, title="Accuracy")
print("Mean accuracy - {}".format(np.mean(acc_log)))
# Out:
# 100%|██████████| 1860/1860 [05:32<00:00,  5.73it/s]
# Mean accuracy - 0.9812920026881721
